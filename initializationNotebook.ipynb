# %%
# %sql
-- Bootstrap catalog + schemas + tables for ontology crawling in Databricks
-- Source datasets: samples.tpcds_sf1 and samples.wanderbricks
-- Target catalog: uw_team_h
--
-- Notes:
-- 1) Assumes you have permissions to create/use the target catalog and schemas.
-- 2) Uses CREATE OR REPLACE TABLE AS SELECT to materialize copies from the built-in samples catalog.
-- 3) Adds comments to the catalog, schemas, selected raw tables, and curated feature tables.

-- COMMENT ON CATALOG uw_team_h IS 'Sandbox catalog for ontology crawling, feature discovery, and agent traversal experiments.';

USE CATALOG uw_team_h;

CREATE SCHEMA IF NOT EXISTS uw_team_h.retail_dimensions
  COMMENT 'Retail reference and dimension tables copied from samples.tpcds_sf1.';

CREATE SCHEMA IF NOT EXISTS uw_team_h.retail_facts
  COMMENT 'Retail fact and event tables copied from samples.tpcds_sf1.';

CREATE SCHEMA IF NOT EXISTS uw_team_h.travel_entities
  COMMENT 'Travel marketplace entity tables copied from samples.wanderbricks.';

CREATE SCHEMA IF NOT EXISTS uw_team_h.travel_events
  COMMENT 'Travel marketplace event, transaction, and behavioral tables copied from samples.wanderbricks.';

CREATE SCHEMA IF NOT EXISTS uw_team_h.agent_features
  COMMENT 'Curated, semantically rich feature tables intended to help ontology and feature-recommendation agents.';

-- ---------------------------------------------------------------------
-- TPC-DS reference / dimension tables
-- ---------------------------------------------------------------------
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.call_center            AS SELECT * FROM samples.tpcds_sf1.call_center;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.catalog_page           AS SELECT * FROM samples.tpcds_sf1.catalog_page;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.customer               AS SELECT * FROM samples.tpcds_sf1.customer;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.customer_address       AS SELECT * FROM samples.tpcds_sf1.customer_address;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.customer_demographics  AS SELECT * FROM samples.tpcds_sf1.customer_demographics;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.date_dim               AS SELECT * FROM samples.tpcds_sf1.date_dim;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.household_demographics AS SELECT * FROM samples.tpcds_sf1.household_demographics;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.income_band            AS SELECT * FROM samples.tpcds_sf1.income_band;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.item                   AS SELECT * FROM samples.tpcds_sf1.item;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.promotion              AS SELECT * FROM samples.tpcds_sf1.promotion;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.reason                 AS SELECT * FROM samples.tpcds_sf1.reason;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.ship_mode              AS SELECT * FROM samples.tpcds_sf1.ship_mode;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.store                  AS SELECT * FROM samples.tpcds_sf1.store;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.time_dim               AS SELECT * FROM samples.tpcds_sf1.time_dim;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.warehouse              AS SELECT * FROM samples.tpcds_sf1.warehouse;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.web_page               AS SELECT * FROM samples.tpcds_sf1.web_page;
CREATE OR REPLACE TABLE uw_team_h.retail_dimensions.web_site               AS SELECT * FROM samples.tpcds_sf1.web_site;

-- ---------------------------------------------------------------------
-- TPC-DS fact / event tables
-- ---------------------------------------------------------------------
CREATE OR REPLACE TABLE uw_team_h.retail_facts.catalog_returns AS SELECT * FROM samples.tpcds_sf1.catalog_returns;
CREATE OR REPLACE TABLE uw_team_h.retail_facts.catalog_sales   AS SELECT * FROM samples.tpcds_sf1.catalog_sales;
CREATE OR REPLACE TABLE uw_team_h.retail_facts.inventory       AS SELECT * FROM samples.tpcds_sf1.inventory;
CREATE OR REPLACE TABLE uw_team_h.retail_facts.store_returns   AS SELECT * FROM samples.tpcds_sf1.store_returns;
CREATE OR REPLACE TABLE uw_team_h.retail_facts.store_sales     AS SELECT * FROM samples.tpcds_sf1.store_sales;
CREATE OR REPLACE TABLE uw_team_h.retail_facts.web_returns     AS SELECT * FROM samples.tpcds_sf1.web_returns;
CREATE OR REPLACE TABLE uw_team_h.retail_facts.web_sales       AS SELECT * FROM samples.tpcds_sf1.web_sales;

-- ---------------------------------------------------------------------
-- Wanderbricks entity tables
-- ---------------------------------------------------------------------
CREATE OR REPLACE TABLE uw_team_h.travel_entities.amenities          AS SELECT * FROM samples.wanderbricks.amenities;
CREATE OR REPLACE TABLE uw_team_h.travel_entities.countries          AS SELECT * FROM samples.wanderbricks.countries;
CREATE OR REPLACE TABLE uw_team_h.travel_entities.destinations       AS SELECT * FROM samples.wanderbricks.destinations;
CREATE OR REPLACE TABLE uw_team_h.travel_entities.employees          AS SELECT * FROM samples.wanderbricks.employees;
CREATE OR REPLACE TABLE uw_team_h.travel_entities.hosts              AS SELECT * FROM samples.wanderbricks.hosts;
CREATE OR REPLACE TABLE uw_team_h.travel_entities.properties         AS SELECT * FROM samples.wanderbricks.properties;
CREATE OR REPLACE TABLE uw_team_h.travel_entities.property_amenities AS SELECT * FROM samples.wanderbricks.property_amenities;
CREATE OR REPLACE TABLE uw_team_h.travel_entities.property_images    AS SELECT * FROM samples.wanderbricks.property_images;
CREATE OR REPLACE TABLE uw_team_h.travel_entities.users              AS SELECT * FROM samples.wanderbricks.users;

-- ---------------------------------------------------------------------
-- Wanderbricks event / transaction / behavior tables
-- ---------------------------------------------------------------------
CREATE OR REPLACE TABLE uw_team_h.travel_events.booking_updates        AS SELECT * FROM samples.wanderbricks.booking_updates;
CREATE OR REPLACE TABLE uw_team_h.travel_events.bookings               AS SELECT * FROM samples.wanderbricks.bookings;
CREATE OR REPLACE TABLE uw_team_h.travel_events.clickstream            AS SELECT * FROM samples.wanderbricks.clickstream;
CREATE OR REPLACE TABLE uw_team_h.travel_events.customer_support_logs  AS SELECT * FROM samples.wanderbricks.customer_support_logs;
CREATE OR REPLACE TABLE uw_team_h.travel_events.page_views             AS SELECT * FROM samples.wanderbricks.page_views;
CREATE OR REPLACE TABLE uw_team_h.travel_events.payments               AS SELECT * FROM samples.wanderbricks.payments;
CREATE OR REPLACE TABLE uw_team_h.travel_events.reviews                AS SELECT * FROM samples.wanderbricks.reviews;

-- ---------------------------------------------------------------------
-- Table comments: keep these focused on ontology traversal hints.
-- ---------------------------------------------------------------------
COMMENT ON TABLE uw_team_h.retail_dimensions.customer IS
  'Retail customer master records. Useful join hub for customer-level features across store, catalog, and web sales.';

COMMENT ON TABLE uw_team_h.retail_dimensions.item IS
  'Retail item dimension. Useful join hub for SKU-level or product-level features across sales, returns, and inventory.';

COMMENT ON TABLE uw_team_h.retail_dimensions.date_dim IS
  'Canonical retail date dimension for time-based rollups and seasonality features.';

COMMENT ON TABLE uw_team_h.retail_dimensions.store IS
  'Retail store dimension for geography and channel-specific performance features.';

COMMENT ON TABLE uw_team_h.retail_facts.store_sales IS
  'Point-of-sale sales fact table. Key source for customer spend, item demand, store performance, and time-series features.';

COMMENT ON TABLE uw_team_h.retail_facts.catalog_sales IS
  'Catalog order sales fact table. Useful for channel mix, customer propensity, and item affinity features.';

COMMENT ON TABLE uw_team_h.retail_facts.web_sales IS
  'E-commerce sales fact table. Useful for digital demand, recency-frequency-monetary analysis, and online conversion features.';

COMMENT ON TABLE uw_team_h.retail_facts.inventory IS
  'Inventory snapshots by item and warehouse/date. Useful for stockout, availability, and supply-demand features.';

COMMENT ON TABLE uw_team_h.travel_entities.users IS
  'Traveler and customer entity records. Primary entity for user-level travel features and behavioral joins.';

COMMENT ON TABLE uw_team_h.travel_entities.properties IS
  'Property listing entity records. Primary entity for property-level demand, quality, and pricing features.';

COMMENT ON TABLE uw_team_h.travel_entities.hosts IS
  'Host entity records that own or operate property listings.';

COMMENT ON TABLE uw_team_h.travel_entities.destinations IS
  'Destination lookup table referenced by property listings for location-aware travel features.';

COMMENT ON TABLE uw_team_h.travel_events.bookings IS
  'Reservation fact table with user, property, stay dates, total amount, and booking status. Primary source for conversion and revenue features.';

COMMENT ON TABLE uw_team_h.travel_events.payments IS
  'Payment records tied to bookings. Useful for payment reliability, settlement, and revenue realization features.';

COMMENT ON TABLE uw_team_h.travel_events.reviews IS
  'Post-stay review events with ratings and comments. Useful for property quality and guest satisfaction features.';

COMMENT ON TABLE uw_team_h.travel_events.clickstream IS
  'Behavioral event stream with nested metadata such as device and referrer. Useful for session, funnel, and intent features.';

COMMENT ON TABLE uw_team_h.travel_events.page_views IS
  'Page view activity for users and properties. Useful for browsing-intent and property engagement features.';

COMMENT ON TABLE uw_team_h.travel_events.customer_support_logs IS
  'Support interactions tied to users. Useful for friction, issue, and post-booking support features.';

-- ---------------------------------------------------------------------
-- Curated feature tables for the agent to discover.
-- These are intentionally simple and semantically rich.
-- ---------------------------------------------------------------------
CREATE OR REPLACE TABLE uw_team_h.agent_features.travel_user_booking_features AS
SELECT
  b.user_id,
  COUNT(*) AS total_bookings,
  SUM(CASE WHEN lower(b.status) IN ('confirmed', 'completed') THEN 1 ELSE 0 END) AS successful_bookings,
  SUM(CASE WHEN lower(b.status) IN ('cancelled', 'canceled') THEN 1 ELSE 0 END) AS cancelled_bookings,
  ROUND(SUM(b.total_amount), 2) AS gross_booking_amount,
  ROUND(AVG(b.total_amount), 2) AS avg_booking_amount,
  MIN(b.check_in) AS first_check_in_date,
  MAX(b.check_in) AS most_recent_check_in_date
FROM uw_team_h.travel_events.bookings b
GROUP BY b.user_id;

COMMENT ON TABLE uw_team_h.agent_features.travel_user_booking_features IS
  'User-level booking aggregates derived from bookings. Good candidate feature table for churn, conversion, rebooking, and customer value models.';

COMMENT ON COLUMN uw_team_h.agent_features.travel_user_booking_features.user_id IS
  'Primary user entity key from the bookings table.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_user_booking_features.total_bookings IS
  'Total number of bookings observed for the user.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_user_booking_features.successful_bookings IS
  'Count of bookings with confirmed or completed status.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_user_booking_features.cancelled_bookings IS
  'Count of bookings with canceled or cancelled status.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_user_booking_features.gross_booking_amount IS
  'Total booked monetary value summed across all user bookings.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_user_booking_features.avg_booking_amount IS
  'Average monetary value per booking for the user.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_user_booking_features.first_check_in_date IS
  'Earliest observed stay start date for the user.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_user_booking_features.most_recent_check_in_date IS
  'Most recent observed stay start date for the user.';

CREATE OR REPLACE TABLE uw_team_h.agent_features.travel_property_quality_features AS
WITH booking_agg AS (
  SELECT
    property_id,
    COUNT(*) AS total_bookings,
    ROUND(SUM(total_amount), 2) AS gross_booking_amount,
    ROUND(AVG(total_amount), 2) AS avg_booking_amount
  FROM uw_team_h.travel_events.bookings
  GROUP BY property_id
),
review_agg AS (
  SELECT
    property_id,
    ROUND(AVG(rating), 2) AS avg_rating,
    COUNT(*) AS review_count
  FROM uw_team_h.travel_events.reviews
  WHERE is_deleted = false
  GROUP BY property_id
)
SELECT
  p.property_id,
  p.title AS property_title,
  p.property_type,
  COALESCE(b.total_bookings, 0) AS total_bookings,
  COALESCE(b.gross_booking_amount, 0.0) AS gross_booking_amount,
  COALESCE(b.avg_booking_amount, 0.0) AS avg_booking_amount,
  COALESCE(r.avg_rating, 0.0) AS avg_rating,
  COALESCE(r.review_count, 0) AS review_count
FROM uw_team_h.travel_entities.properties p
LEFT JOIN booking_agg b
  ON p.property_id = b.property_id
LEFT JOIN review_agg r
  ON p.property_id = r.property_id;

COMMENT ON TABLE uw_team_h.agent_features.travel_property_quality_features IS
  'Property-level aggregates that combine booking demand and guest review quality. Good candidate feature table for ranking, pricing, and occupancy models.';

COMMENT ON COLUMN uw_team_h.agent_features.travel_property_quality_features.property_id IS
  'Primary property entity key from the properties table.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_property_quality_features.property_title IS
  'Human-readable property title from the properties table.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_property_quality_features.property_type IS
  'Property classification such as apartment, house, or similar listing type.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_property_quality_features.total_bookings IS
  'Number of bookings associated with the property.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_property_quality_features.gross_booking_amount IS
  'Total booked monetary value across all bookings for the property.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_property_quality_features.avg_booking_amount IS
  'Average booking amount for the property.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_property_quality_features.avg_rating IS
  'Average rating across non-deleted reviews for the property.';
COMMENT ON COLUMN uw_team_h.agent_features.travel_property_quality_features.review_count IS
  'Number of non-deleted reviews used to compute the property rating statistics.';

-- ---------------------------------------------------------------------
-- Suggested crawl queries for your ontology service.
-- ---------------------------------------------------------------------
-- All schemas in this catalog:
-- SELECT catalog_name, schema_name, comment
-- FROM system.information_schema.schemata
-- WHERE catalog_name = 'uw_team_h'
-- ORDER BY schema_name;

-- All tables in this catalog:
-- SELECT table_catalog, table_schema, table_name, table_type, comment
-- FROM system.information_schema.tables
-- WHERE table_catalog = 'uw_team_h'
-- ORDER BY table_schema, table_name;

-- All columns in this catalog:
-- SELECT table_catalog, table_schema, table_name, column_name, data_type, full_data_type, comment
-- FROM system.information_schema.columns
-- WHERE table_catalog = 'uw_team_h'
-- ORDER BY table_schema, table_name, ordinal_position;

-- Stable single-table metadata for parsing:
-- DESCRIBE TABLE AS JSON uw_team_h.agent_features.travel_property_quality_features;

# %%
# %sql
-- Patch comments across all user schemas in catalog uw_team_h
-- Generated to ensure non-null table and column comments for ontology crawling tests.
USE CATALOG uw_team_h;

COMMENT ON SCHEMA uw_team_h.retail_channel IS 'Retail channel and touchpoint dimensions for stores, call centers, websites, pages, dates, times, and shipping methods.';

COMMENT ON SCHEMA uw_team_h.retail_customer IS 'Retail customer and household profile dimensions for customer-level analysis and segmentation.';

COMMENT ON SCHEMA uw_team_h.retail_dimensions IS 'Retail reference and dimension tables copied from TPC-DS for broad ontology crawling.';

COMMENT ON SCHEMA uw_team_h.retail_facts IS 'Retail transactional fact tables for sales, returns, and inventory snapshots.';

COMMENT ON SCHEMA uw_team_h.retail_product IS 'Retail product, promotion, and warehouse dimensions.';

COMMENT ON SCHEMA uw_team_h.retail_transactions IS 'Retail transactional sales and returns tables organized for event-oriented exploration.';

COMMENT ON SCHEMA uw_team_h.travel_entities IS 'Travel marketplace entity tables including users, hosts, properties, destinations, and amenities.';

COMMENT ON SCHEMA uw_team_h.travel_events IS 'Travel marketplace behavioral, booking, payment, support, and review events.';

COMMENT ON SCHEMA uw_team_h.travel_identity IS 'Travel identity and actor tables for users, hosts, employees, and countries.';

COMMENT ON SCHEMA uw_team_h.travel_supply IS 'Travel supply-side reference tables for destinations and amenities.';

COMMENT ON TABLE uw_team_h.retail_channel.call_center IS 'Call center dimension with identifiers, dates, staffing, management, market, and address attributes.';
COMMENT ON TABLE uw_team_h.retail_channel.catalog_page IS 'Catalog page dimension describing printed catalog pages and their merchandising attributes.';
COMMENT ON TABLE uw_team_h.retail_channel.date_dim IS 'Calendar date dimension for rollups, seasonality, and time-based joins.';
COMMENT ON TABLE uw_team_h.retail_channel.reason IS 'Reference table of return or adjustment reasons.';
COMMENT ON TABLE uw_team_h.retail_channel.ship_mode IS 'Reference table of shipping methods, carriers, and contracts.';
COMMENT ON TABLE uw_team_h.retail_channel.store IS 'Store dimension with operations, staffing, market, and address attributes.';
COMMENT ON TABLE uw_team_h.retail_channel.time_dim IS 'Time-of-day dimension for intraday analysis.';
COMMENT ON TABLE uw_team_h.retail_channel.web_page IS 'Web page dimension with page ownership, URL, and content statistics.';
COMMENT ON TABLE uw_team_h.retail_channel.web_site IS 'Website dimension with operational, market, and address attributes.';
COMMENT ON TABLE uw_team_h.retail_customer.customer IS 'Customer dimension with profile, demographics, and lifecycle dates.';
COMMENT ON TABLE uw_team_h.retail_customer.customer_address IS 'Customer address dimension for geography and location analysis.';
COMMENT ON TABLE uw_team_h.retail_customer.customer_demographics IS 'Customer demographic segment attributes such as gender, marital status, and education.';
COMMENT ON TABLE uw_team_h.retail_customer.household_demographics IS 'Household demographic attributes including income band, dependents, and vehicles.';
COMMENT ON TABLE uw_team_h.retail_customer.income_band IS 'Income band reference table with lower and upper bounds.';
COMMENT ON TABLE uw_team_h.retail_dimensions.call_center IS 'Call center dimension with identifiers, dates, staffing, management, market, and address attributes.';
COMMENT ON TABLE uw_team_h.retail_dimensions.catalog_page IS 'Catalog page dimension describing printed catalog pages and their merchandising attributes.';
COMMENT ON TABLE uw_team_h.retail_dimensions.customer IS 'Customer dimension with profile, demographics, and lifecycle dates.';
COMMENT ON TABLE uw_team_h.retail_dimensions.customer_address IS 'Customer address dimension for geography and location analysis.';
COMMENT ON TABLE uw_team_h.retail_dimensions.customer_demographics IS 'Customer demographic segment attributes such as gender, marital status, and education.';
COMMENT ON TABLE uw_team_h.retail_dimensions.date_dim IS 'Calendar date dimension for rollups, seasonality, and time-based joins.';
COMMENT ON TABLE uw_team_h.retail_dimensions.household_demographics IS 'Household demographic attributes including income band, dependents, and vehicles.';
COMMENT ON TABLE uw_team_h.retail_dimensions.income_band IS 'Income band reference table with lower and upper bounds.';
COMMENT ON TABLE uw_team_h.retail_dimensions.item IS 'Product dimension for SKU, pricing, brand, category, and manufacturing attributes.';
COMMENT ON TABLE uw_team_h.retail_dimensions.promotion IS 'Promotion dimension describing campaigns, channels, and promotional cost or target metrics.';
COMMENT ON TABLE uw_team_h.retail_dimensions.reason IS 'Reference table of return or adjustment reasons.';
COMMENT ON TABLE uw_team_h.retail_dimensions.ship_mode IS 'Reference table of shipping methods, carriers, and contracts.';
COMMENT ON TABLE uw_team_h.retail_dimensions.store IS 'Store dimension with operations, staffing, market, and address attributes.';
COMMENT ON TABLE uw_team_h.retail_dimensions.time_dim IS 'Time-of-day dimension for intraday analysis.';
COMMENT ON TABLE uw_team_h.retail_dimensions.warehouse IS 'Warehouse dimension with facility and address attributes.';
COMMENT ON TABLE uw_team_h.retail_dimensions.web_page IS 'Web page dimension with page ownership, URL, and content statistics.';
COMMENT ON TABLE uw_team_h.retail_dimensions.web_site IS 'Website dimension with operational, market, and address attributes.';
COMMENT ON TABLE uw_team_h.retail_facts.catalog_returns IS 'Catalog returns fact table capturing returned quantities and refund-related amounts.';
COMMENT ON TABLE uw_team_h.retail_facts.catalog_sales IS 'Catalog sales fact table capturing ordered quantities, prices, discounts, and shipping costs.';
COMMENT ON TABLE uw_team_h.retail_facts.inventory IS 'Inventory snapshot table by date, item, and warehouse.';
COMMENT ON TABLE uw_team_h.retail_facts.store_returns IS 'Store returns fact table capturing returned quantities and refund-related amounts.';
COMMENT ON TABLE uw_team_h.retail_facts.store_sales IS 'Store sales fact table capturing point-of-sale quantities, prices, discounts, and net paid amounts.';
COMMENT ON TABLE uw_team_h.retail_facts.web_returns IS 'Web returns fact table capturing returned quantities and refund-related amounts.';
COMMENT ON TABLE uw_team_h.retail_facts.web_sales IS 'Web sales fact table capturing online order quantities, prices, discounts, and shipping costs.';
COMMENT ON TABLE uw_team_h.retail_product.inventory IS 'Inventory snapshot table by date, item, and warehouse.';
COMMENT ON TABLE uw_team_h.retail_product.item IS 'Product dimension for SKU, pricing, brand, category, and manufacturing attributes.';
COMMENT ON TABLE uw_team_h.retail_product.promotion IS 'Promotion dimension describing campaigns, channels, and promotional cost or target metrics.';
COMMENT ON TABLE uw_team_h.retail_product.warehouse IS 'Warehouse dimension with facility and address attributes.';
COMMENT ON TABLE uw_team_h.retail_transactions.catalog_returns IS 'Catalog returns fact table capturing returned quantities and refund-related amounts.';
COMMENT ON TABLE uw_team_h.retail_transactions.catalog_sales IS 'Catalog sales fact table capturing ordered quantities, prices, discounts, and shipping costs.';
COMMENT ON TABLE uw_team_h.retail_transactions.store_returns IS 'Store returns fact table capturing returned quantities and refund-related amounts.';
COMMENT ON TABLE uw_team_h.retail_transactions.store_sales IS 'Store sales fact table capturing point-of-sale quantities, prices, discounts, and net paid amounts.';
COMMENT ON TABLE uw_team_h.retail_transactions.web_returns IS 'Web returns fact table capturing returned quantities and refund-related amounts.';
COMMENT ON TABLE uw_team_h.retail_transactions.web_sales IS 'Web sales fact table capturing online order quantities, prices, discounts, and shipping costs.';
COMMENT ON TABLE uw_team_h.travel_entities.amenities IS 'Amenity reference table describing property amenities and their category.';
COMMENT ON TABLE uw_team_h.travel_entities.countries IS 'Country reference table with country code and continent.';
COMMENT ON TABLE uw_team_h.travel_entities.destinations IS 'Destination reference table for travel markets and their descriptions.';
COMMENT ON TABLE uw_team_h.travel_entities.employees IS 'Employee records for travel operations or support teams.';
COMMENT ON TABLE uw_team_h.travel_entities.hosts IS 'Host records for property owners or operators.';
COMMENT ON TABLE uw_team_h.travel_entities.properties IS 'Property listing records with location, price, and capacity attributes.';
COMMENT ON TABLE uw_team_h.travel_entities.property_amenities IS 'Bridge table linking properties to amenities.';
COMMENT ON TABLE uw_team_h.travel_entities.property_images IS 'Property image records with ordering and primary-image flags.';
COMMENT ON TABLE uw_team_h.travel_entities.users IS 'Traveler or customer user records.';
COMMENT ON TABLE uw_team_h.travel_events.booking_updates IS 'Audit-style updates to bookings over time.';
COMMENT ON TABLE uw_team_h.travel_events.bookings IS 'Travel booking transaction records.';
COMMENT ON TABLE uw_team_h.travel_events.clickstream IS 'Raw behavioral event records from digital interactions.';
COMMENT ON TABLE uw_team_h.travel_events.customer_support_logs IS 'Customer support conversation or ticket logs.';
COMMENT ON TABLE uw_team_h.travel_events.page_views IS 'Page view event records for digital behavior analysis.';
COMMENT ON TABLE uw_team_h.travel_events.payments IS 'Payment transaction records associated with bookings.';
COMMENT ON TABLE uw_team_h.travel_events.reviews IS 'Review records describing user feedback and ratings.';
COMMENT ON TABLE uw_team_h.travel_identity.countries IS 'Country reference table with country code and continent.';
COMMENT ON TABLE uw_team_h.travel_identity.employees IS 'Employee records for travel operations or support teams.';
COMMENT ON TABLE uw_team_h.travel_identity.hosts IS 'Host records for property owners or operators.';
COMMENT ON TABLE uw_team_h.travel_identity.users IS 'Traveler or customer user records.';
COMMENT ON TABLE uw_team_h.travel_supply.amenities IS 'Amenity reference table describing property amenities and their category.';
COMMENT ON TABLE uw_team_h.travel_supply.destinations IS 'Destination reference table for travel markets and their descriptions.';

-- retail_channel.call_center
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_call_center_sk IS 'Surrogate key for the related call center.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_call_center_id IS 'Business identifier for the call center.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_rec_start_date IS 'Record-effective start date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_rec_end_date IS 'Record-effective end date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_closed_date_sk IS 'Surrogate key for the closure date.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_open_date_sk IS 'Surrogate key for the opening date.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_name IS 'Name of the entity.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_class IS 'Class or segment name.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_employees IS 'Number of employees assigned to the facility.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_sq_ft IS 'Floor space in square feet.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_hours IS 'Operating hours.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_manager IS 'Store manager name.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_mkt_id IS 'Identifier for the market.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_mkt_class IS 'Market classification.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_mkt_desc IS 'Description of the market.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_market_manager IS 'Manager responsible for the market.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_division IS 'Identifier for the division.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_division_name IS 'Name of the division.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_company IS 'Identifier for the company.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_company_name IS 'Name of the company.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_street_number IS 'Street number portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_street_name IS 'Street name portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_street_type IS 'Street type or suffix for the address.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_suite_number IS 'Suite, unit, or apartment number.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_city IS 'City name.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_county IS 'County or local administrative area.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_state IS 'State or province code or name.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_zip IS 'Postal or ZIP code.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_country IS 'Country name.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_gmt_offset IS 'Offset from GMT/UTC for the location.';
COMMENT ON COLUMN uw_team_h.retail_channel.call_center.cc_tax_percentage IS 'Applicable tax percentage.';

-- retail_channel.catalog_page
COMMENT ON COLUMN uw_team_h.retail_channel.catalog_page.cp_catalog_page_sk IS 'Surrogate key for the related catalog page.';
COMMENT ON COLUMN uw_team_h.retail_channel.catalog_page.cp_catalog_page_id IS 'Catalog page identifier for the catalog page record.';
COMMENT ON COLUMN uw_team_h.retail_channel.catalog_page.cp_start_date_sk IS 'Surrogate key for the start date.';
COMMENT ON COLUMN uw_team_h.retail_channel.catalog_page.cp_end_date_sk IS 'Surrogate key for the end date.';
COMMENT ON COLUMN uw_team_h.retail_channel.catalog_page.cp_department IS 'Department for the catalog page record.';
COMMENT ON COLUMN uw_team_h.retail_channel.catalog_page.cp_catalog_number IS 'Catalog edition or issue number.';
COMMENT ON COLUMN uw_team_h.retail_channel.catalog_page.cp_catalog_page_number IS 'Page number within the catalog.';
COMMENT ON COLUMN uw_team_h.retail_channel.catalog_page.cp_description IS 'Text description.';
COMMENT ON COLUMN uw_team_h.retail_channel.catalog_page.cp_type IS 'Type classification.';

-- retail_channel.date_dim
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_date_sk IS 'Surrogate key for the calendar date.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_date_id IS 'Business identifier for the calendar date.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_date IS 'Calendar date value.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_month_seq IS 'Sequential number for the month across the date dimension timeline.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_week_seq IS 'Sequential number for the week across the date dimension timeline.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_quarter_seq IS 'Sequential number for the quarter across the date dimension timeline.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_year IS 'Calendar year number.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_dow IS 'Day-of-week number.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_moy IS 'Month-of-year number.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_dom IS 'Day-of-month number.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_qoy IS 'Quarter-of-year number.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_fy_year IS 'Fiscal year number.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_fy_quarter_seq IS 'Sequential fiscal quarter number across the timeline.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_fy_week_seq IS 'Sequential fiscal week number across the timeline.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_day_name IS 'Name of the day of week.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_quarter_name IS 'Display name of the quarter.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_holiday IS 'Flag indicating whether the date is a holiday.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_weekend IS 'Flag indicating whether the date falls on a weekend.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_following_holiday IS 'Flag indicating whether the next date is a holiday.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_first_dom IS 'Day-of-month value for the first day in the month.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_last_dom IS 'Day-of-month value for the last day in the month.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_same_day_ly IS 'Surrogate key for the same day in the prior year.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_same_day_lq IS 'Surrogate key for the same day in the prior quarter.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_current_day IS 'Flag indicating whether the record represents the current day in the benchmark context.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_current_week IS 'Flag indicating whether the record represents the current week in the benchmark context.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_current_month IS 'Flag indicating whether the record represents the current month in the benchmark context.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_current_quarter IS 'Flag indicating whether the record represents the current quarter in the benchmark context.';
COMMENT ON COLUMN uw_team_h.retail_channel.date_dim.d_current_year IS 'Flag indicating whether the record represents the current year in the benchmark context.';

-- retail_channel.reason
COMMENT ON COLUMN uw_team_h.retail_channel.reason.r_reason_sk IS 'Surrogate key for the related return reason.';
COMMENT ON COLUMN uw_team_h.retail_channel.reason.r_reason_id IS 'Business identifier for the reason.';
COMMENT ON COLUMN uw_team_h.retail_channel.reason.r_reason_desc IS 'Text description of the reason.';

-- retail_channel.ship_mode
COMMENT ON COLUMN uw_team_h.retail_channel.ship_mode.sm_ship_mode_sk IS 'Surrogate key for the related shipping mode.';
COMMENT ON COLUMN uw_team_h.retail_channel.ship_mode.sm_ship_mode_id IS 'Business identifier for the shipping mode.';
COMMENT ON COLUMN uw_team_h.retail_channel.ship_mode.sm_type IS 'Type classification.';
COMMENT ON COLUMN uw_team_h.retail_channel.ship_mode.sm_code IS 'Short code value.';
COMMENT ON COLUMN uw_team_h.retail_channel.ship_mode.sm_carrier IS 'Carrier handling the shipment.';
COMMENT ON COLUMN uw_team_h.retail_channel.ship_mode.sm_contract IS 'Contract or service agreement associated with the shipping mode.';

-- retail_channel.store
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_store_sk IS 'Surrogate key for the related store.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_store_id IS 'Business identifier for the store.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_rec_start_date IS 'Record-effective start date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_rec_end_date IS 'Record-effective end date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_closed_date_sk IS 'Surrogate key for the closure date.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_store_name IS 'Store name.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_number_employees IS 'Number of employees assigned to the store.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_floor_space IS 'Store floor space in square feet.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_hours IS 'Operating hours.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_manager IS 'Store manager name.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_market_id IS 'Identifier for the store market.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_geography_class IS 'Geographic classification for the store.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_market_desc IS 'Description of the store market.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_market_manager IS 'Manager responsible for the market.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_division_id IS 'Identifier for the store division.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_division_name IS 'Name of the division.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_company_id IS 'Identifier for the operating company.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_company_name IS 'Name of the company.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_street_number IS 'Street number portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_street_name IS 'Street name portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_street_type IS 'Street type or suffix for the address.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_suite_number IS 'Suite, unit, or apartment number.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_city IS 'City name.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_county IS 'County or local administrative area.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_state IS 'State or province code or name.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_zip IS 'Postal or ZIP code.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_country IS 'Country name.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_gmt_offset IS 'Offset from GMT/UTC for the location.';
COMMENT ON COLUMN uw_team_h.retail_channel.store.s_tax_precentage IS 'Applicable tax percentage for the store. Note: source column name contains a typo.';

-- retail_channel.time_dim
COMMENT ON COLUMN uw_team_h.retail_channel.time_dim.t_time_sk IS 'Surrogate key for the related time record.';
COMMENT ON COLUMN uw_team_h.retail_channel.time_dim.t_time_id IS 'Business identifier for the time-of-day record.';
COMMENT ON COLUMN uw_team_h.retail_channel.time_dim.t_time IS 'Time-of-day value or encoded time.';
COMMENT ON COLUMN uw_team_h.retail_channel.time_dim.t_hour IS 'Hour component of the time.';
COMMENT ON COLUMN uw_team_h.retail_channel.time_dim.t_minute IS 'Minute component of the time.';
COMMENT ON COLUMN uw_team_h.retail_channel.time_dim.t_second IS 'Second component of the time.';
COMMENT ON COLUMN uw_team_h.retail_channel.time_dim.t_am_pm IS 'AM/PM indicator.';
COMMENT ON COLUMN uw_team_h.retail_channel.time_dim.t_shift IS 'Shift label for the time period.';
COMMENT ON COLUMN uw_team_h.retail_channel.time_dim.t_sub_shift IS 'Sub-shift label for the time period.';
COMMENT ON COLUMN uw_team_h.retail_channel.time_dim.t_meal_time IS 'Meal-period label associated with the time.';

-- retail_channel.web_page
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_web_page_sk IS 'Surrogate key for the related web page.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_web_page_id IS 'Business identifier for the web page.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_rec_start_date IS 'Record-effective start date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_rec_end_date IS 'Record-effective end date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_creation_date_sk IS 'Surrogate key for the page creation date.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_access_date_sk IS 'Surrogate key for the page access date.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_autogen_flag IS 'Flag indicating whether the page was auto-generated.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_customer_sk IS 'Surrogate key for the related customer.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_url IS 'URL for the page or asset.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_type IS 'Type classification.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_char_count IS 'Character count for the page content.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_link_count IS 'Number of links on the page.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_image_count IS 'Number of images on the page.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_page.wp_max_ad_count IS 'Maximum number of ads on the page.';

-- retail_channel.web_site
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_site_sk IS 'Site surrogate key for the website record.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_site_id IS 'Site identifier for the website record.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_rec_start_date IS 'Record-effective start date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_rec_end_date IS 'Record-effective end date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_name IS 'Name of the entity.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_open_date_sk IS 'Surrogate key for the opening date.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_close_date_sk IS 'Surrogate key for the closing date.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_class IS 'Class or segment name.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_manager IS 'Store manager name.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_mkt_id IS 'Identifier for the market.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_mkt_class IS 'Market classification.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_mkt_desc IS 'Description of the market.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_market_manager IS 'Manager responsible for the market.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_company_id IS 'Identifier for the operating company.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_company_name IS 'Name of the company.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_street_number IS 'Street number portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_street_name IS 'Street name portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_street_type IS 'Street type or suffix for the address.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_suite_number IS 'Suite, unit, or apartment number.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_city IS 'City name.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_county IS 'County or local administrative area.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_state IS 'State or province code or name.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_zip IS 'Postal or ZIP code.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_country IS 'Country name.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_gmt_offset IS 'Offset from GMT/UTC for the location.';
COMMENT ON COLUMN uw_team_h.retail_channel.web_site.web_tax_percentage IS 'Applicable tax percentage.';

-- retail_customer.customer
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_customer_sk IS 'Surrogate key for the related customer.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_customer_id IS 'Customer identifier for the customer record.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_current_cdemo_sk IS 'Surrogate key for the customer''s current demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_current_hdemo_sk IS 'Surrogate key for the customer''s current household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_current_addr_sk IS 'Surrogate key for the customer''s current address.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_first_shipto_date_sk IS 'Surrogate key for the first ship-to date for the customer.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_first_sales_date_sk IS 'Surrogate key for the first sales date for the customer.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_salutation IS 'Customer salutation.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_first_name IS 'Customer first name.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_last_name IS 'Customer last name.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_preferred_cust_flag IS 'Flag indicating whether the customer is preferred.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_birth_day IS 'Day of month of birth.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_birth_month IS 'Month of birth.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_birth_year IS 'Year of birth.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_birth_country IS 'Country of birth.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_login IS 'Customer login name.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_email_address IS 'Customer email address.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_last_review_date_sk IS 'Last review date surrogate key for the customer record.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer.c_last_review_date IS 'Date of the customer''s most recent review.';

-- retail_customer.customer_address
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_address_sk IS 'Address surrogate key for the customer address record.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_address_id IS 'Address identifier for the customer address record.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_street_number IS 'Street number portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_street_name IS 'Street name portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_street_type IS 'Street type or suffix for the address.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_suite_number IS 'Suite, unit, or apartment number.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_city IS 'City name.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_county IS 'County or local administrative area.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_state IS 'State or province code or name.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_zip IS 'Postal or ZIP code.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_country IS 'Country name.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_gmt_offset IS 'Offset from GMT/UTC for the location.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_address.ca_location_type IS 'Classification of the location type.';

-- retail_customer.customer_demographics
COMMENT ON COLUMN uw_team_h.retail_customer.customer_demographics.cd_demo_sk IS 'Surrogate key for the demographic record.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_demographics.cd_gender IS 'Gender attribute.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_demographics.cd_marital_status IS 'Marital status attribute.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_demographics.cd_education_status IS 'Education status attribute.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_demographics.cd_purchase_estimate IS 'Estimated purchase propensity or spending band.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_demographics.cd_credit_rating IS 'Credit rating segment.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_demographics.cd_dep_count IS 'Number of dependents.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_demographics.cd_dep_employed_count IS 'Number of employed dependents.';
COMMENT ON COLUMN uw_team_h.retail_customer.customer_demographics.cd_dep_college_count IS 'Number of dependents in college.';

-- retail_customer.household_demographics
COMMENT ON COLUMN uw_team_h.retail_customer.household_demographics.hd_demo_sk IS 'Surrogate key for the demographic record.';
COMMENT ON COLUMN uw_team_h.retail_customer.household_demographics.hd_income_band_sk IS 'Surrogate key for the linked income band.';
COMMENT ON COLUMN uw_team_h.retail_customer.household_demographics.hd_buy_potential IS 'Estimated household buying potential segment.';
COMMENT ON COLUMN uw_team_h.retail_customer.household_demographics.hd_dep_count IS 'Number of dependents.';
COMMENT ON COLUMN uw_team_h.retail_customer.household_demographics.hd_vehicle_count IS 'Number of vehicles in the household.';

-- retail_customer.income_band
COMMENT ON COLUMN uw_team_h.retail_customer.income_band.ib_income_band_sk IS 'Surrogate key for the linked income band.';
COMMENT ON COLUMN uw_team_h.retail_customer.income_band.ib_lower_bound IS 'Lower bound of the income band.';
COMMENT ON COLUMN uw_team_h.retail_customer.income_band.ib_upper_bound IS 'Upper bound of the income band.';

-- retail_dimensions.call_center
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_call_center_sk IS 'Surrogate key for the related call center.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_call_center_id IS 'Business identifier for the call center.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_rec_start_date IS 'Record-effective start date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_rec_end_date IS 'Record-effective end date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_closed_date_sk IS 'Surrogate key for the closure date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_open_date_sk IS 'Surrogate key for the opening date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_name IS 'Name of the entity.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_class IS 'Class or segment name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_employees IS 'Number of employees assigned to the facility.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_sq_ft IS 'Floor space in square feet.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_hours IS 'Operating hours.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_manager IS 'Store manager name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_mkt_id IS 'Identifier for the market.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_mkt_class IS 'Market classification.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_mkt_desc IS 'Description of the market.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_market_manager IS 'Manager responsible for the market.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_division IS 'Identifier for the division.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_division_name IS 'Name of the division.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_company IS 'Identifier for the company.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_company_name IS 'Name of the company.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_street_number IS 'Street number portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_street_name IS 'Street name portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_street_type IS 'Street type or suffix for the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_suite_number IS 'Suite, unit, or apartment number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_city IS 'City name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_county IS 'County or local administrative area.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_state IS 'State or province code or name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_zip IS 'Postal or ZIP code.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_country IS 'Country name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_gmt_offset IS 'Offset from GMT/UTC for the location.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.call_center.cc_tax_percentage IS 'Applicable tax percentage.';

-- retail_dimensions.catalog_page
COMMENT ON COLUMN uw_team_h.retail_dimensions.catalog_page.cp_catalog_page_sk IS 'Surrogate key for the related catalog page.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.catalog_page.cp_catalog_page_id IS 'Catalog page identifier for the catalog page record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.catalog_page.cp_start_date_sk IS 'Surrogate key for the start date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.catalog_page.cp_end_date_sk IS 'Surrogate key for the end date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.catalog_page.cp_department IS 'Department for the catalog page record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.catalog_page.cp_catalog_number IS 'Catalog edition or issue number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.catalog_page.cp_catalog_page_number IS 'Page number within the catalog.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.catalog_page.cp_description IS 'Text description.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.catalog_page.cp_type IS 'Type classification.';

-- retail_dimensions.customer
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_customer_sk IS 'Surrogate key for the related customer.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_customer_id IS 'Customer identifier for the customer record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_current_cdemo_sk IS 'Surrogate key for the customer''s current demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_current_hdemo_sk IS 'Surrogate key for the customer''s current household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_current_addr_sk IS 'Surrogate key for the customer''s current address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_first_shipto_date_sk IS 'Surrogate key for the first ship-to date for the customer.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_first_sales_date_sk IS 'Surrogate key for the first sales date for the customer.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_salutation IS 'Customer salutation.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_first_name IS 'Customer first name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_last_name IS 'Customer last name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_preferred_cust_flag IS 'Flag indicating whether the customer is preferred.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_birth_day IS 'Day of month of birth.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_birth_month IS 'Month of birth.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_birth_year IS 'Year of birth.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_birth_country IS 'Country of birth.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_login IS 'Customer login name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_email_address IS 'Customer email address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_last_review_date_sk IS 'Last review date surrogate key for the customer record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer.c_last_review_date IS 'Date of the customer''s most recent review.';

-- retail_dimensions.customer_address
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_address_sk IS 'Address surrogate key for the customer address record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_address_id IS 'Address identifier for the customer address record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_street_number IS 'Street number portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_street_name IS 'Street name portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_street_type IS 'Street type or suffix for the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_suite_number IS 'Suite, unit, or apartment number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_city IS 'City name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_county IS 'County or local administrative area.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_state IS 'State or province code or name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_zip IS 'Postal or ZIP code.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_country IS 'Country name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_gmt_offset IS 'Offset from GMT/UTC for the location.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_address.ca_location_type IS 'Classification of the location type.';

-- retail_dimensions.customer_demographics
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_demographics.cd_demo_sk IS 'Surrogate key for the demographic record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_demographics.cd_gender IS 'Gender attribute.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_demographics.cd_marital_status IS 'Marital status attribute.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_demographics.cd_education_status IS 'Education status attribute.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_demographics.cd_purchase_estimate IS 'Estimated purchase propensity or spending band.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_demographics.cd_credit_rating IS 'Credit rating segment.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_demographics.cd_dep_count IS 'Number of dependents.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_demographics.cd_dep_employed_count IS 'Number of employed dependents.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.customer_demographics.cd_dep_college_count IS 'Number of dependents in college.';

-- retail_dimensions.date_dim
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_date_sk IS 'Surrogate key for the calendar date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_date_id IS 'Business identifier for the calendar date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_date IS 'Calendar date value.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_month_seq IS 'Sequential number for the month across the date dimension timeline.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_week_seq IS 'Sequential number for the week across the date dimension timeline.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_quarter_seq IS 'Sequential number for the quarter across the date dimension timeline.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_year IS 'Calendar year number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_dow IS 'Day-of-week number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_moy IS 'Month-of-year number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_dom IS 'Day-of-month number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_qoy IS 'Quarter-of-year number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_fy_year IS 'Fiscal year number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_fy_quarter_seq IS 'Sequential fiscal quarter number across the timeline.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_fy_week_seq IS 'Sequential fiscal week number across the timeline.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_day_name IS 'Name of the day of week.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_quarter_name IS 'Display name of the quarter.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_holiday IS 'Flag indicating whether the date is a holiday.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_weekend IS 'Flag indicating whether the date falls on a weekend.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_following_holiday IS 'Flag indicating whether the next date is a holiday.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_first_dom IS 'Day-of-month value for the first day in the month.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_last_dom IS 'Day-of-month value for the last day in the month.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_same_day_ly IS 'Surrogate key for the same day in the prior year.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_same_day_lq IS 'Surrogate key for the same day in the prior quarter.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_current_day IS 'Flag indicating whether the record represents the current day in the benchmark context.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_current_week IS 'Flag indicating whether the record represents the current week in the benchmark context.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_current_month IS 'Flag indicating whether the record represents the current month in the benchmark context.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_current_quarter IS 'Flag indicating whether the record represents the current quarter in the benchmark context.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.date_dim.d_current_year IS 'Flag indicating whether the record represents the current year in the benchmark context.';

-- retail_dimensions.household_demographics
COMMENT ON COLUMN uw_team_h.retail_dimensions.household_demographics.hd_demo_sk IS 'Surrogate key for the demographic record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.household_demographics.hd_income_band_sk IS 'Surrogate key for the linked income band.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.household_demographics.hd_buy_potential IS 'Estimated household buying potential segment.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.household_demographics.hd_dep_count IS 'Number of dependents.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.household_demographics.hd_vehicle_count IS 'Number of vehicles in the household.';

-- retail_dimensions.income_band
COMMENT ON COLUMN uw_team_h.retail_dimensions.income_band.ib_income_band_sk IS 'Surrogate key for the linked income band.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.income_band.ib_lower_bound IS 'Lower bound of the income band.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.income_band.ib_upper_bound IS 'Upper bound of the income band.';

-- retail_dimensions.item
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_item_id IS 'Item identifier for the item record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_rec_start_date IS 'Record-effective start date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_rec_end_date IS 'Record-effective end date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_item_desc IS 'Text description of the item.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_current_price IS 'Current selling price of the item.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_wholesale_cost IS 'Wholesale cost per unit.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_brand_id IS 'Identifier for the item brand.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_brand IS 'Brand name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_class_id IS 'Identifier for the item class.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_class IS 'Class or segment name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_category_id IS 'Identifier for the item category.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_category IS 'Item category name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_manufact_id IS 'Identifier for the manufacturer.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_manufact IS 'Manufacturer name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_size IS 'Item size attribute.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_formulation IS 'Item formulation attribute.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_color IS 'Item color attribute.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_units IS 'Package or unit-of-measure description.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_container IS 'Container or packaging type.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_manager_id IS 'Identifier for the responsible manager.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.item.i_product_name IS 'Display name of the item or product.';

-- retail_dimensions.promotion
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_promo_sk IS 'Surrogate key for the related promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_promo_id IS 'Business identifier for the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_start_date_sk IS 'Surrogate key for the start date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_end_date_sk IS 'Surrogate key for the end date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_cost IS 'Cost associated with the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_response_target IS 'Target response count or conversion goal for the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_promo_name IS 'Name of the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_channel_dmail IS 'Flag indicating whether direct mail is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_channel_email IS 'Flag indicating whether email is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_channel_catalog IS 'Flag indicating whether catalog distribution is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_channel_tv IS 'Flag indicating whether television is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_channel_radio IS 'Flag indicating whether radio is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_channel_press IS 'Flag indicating whether press or print is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_channel_event IS 'Flag indicating whether events are used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_channel_demo IS 'Flag indicating whether demonstrations are used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_channel_details IS 'Free-text details about the promotional channels.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_purpose IS 'Business purpose of the promotion.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.promotion.p_discount_active IS 'Flag indicating whether a discount is active.';

-- retail_dimensions.reason
COMMENT ON COLUMN uw_team_h.retail_dimensions.reason.r_reason_sk IS 'Surrogate key for the related return reason.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.reason.r_reason_id IS 'Business identifier for the reason.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.reason.r_reason_desc IS 'Text description of the reason.';

-- retail_dimensions.ship_mode
COMMENT ON COLUMN uw_team_h.retail_dimensions.ship_mode.sm_ship_mode_sk IS 'Surrogate key for the related shipping mode.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.ship_mode.sm_ship_mode_id IS 'Business identifier for the shipping mode.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.ship_mode.sm_type IS 'Type classification.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.ship_mode.sm_code IS 'Short code value.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.ship_mode.sm_carrier IS 'Carrier handling the shipment.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.ship_mode.sm_contract IS 'Contract or service agreement associated with the shipping mode.';

-- retail_dimensions.store
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_store_sk IS 'Surrogate key for the related store.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_store_id IS 'Business identifier for the store.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_rec_start_date IS 'Record-effective start date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_rec_end_date IS 'Record-effective end date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_closed_date_sk IS 'Surrogate key for the closure date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_store_name IS 'Store name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_number_employees IS 'Number of employees assigned to the store.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_floor_space IS 'Store floor space in square feet.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_hours IS 'Operating hours.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_manager IS 'Store manager name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_market_id IS 'Identifier for the store market.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_geography_class IS 'Geographic classification for the store.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_market_desc IS 'Description of the store market.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_market_manager IS 'Manager responsible for the market.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_division_id IS 'Identifier for the store division.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_division_name IS 'Name of the division.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_company_id IS 'Identifier for the operating company.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_company_name IS 'Name of the company.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_street_number IS 'Street number portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_street_name IS 'Street name portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_street_type IS 'Street type or suffix for the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_suite_number IS 'Suite, unit, or apartment number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_city IS 'City name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_county IS 'County or local administrative area.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_state IS 'State or province code or name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_zip IS 'Postal or ZIP code.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_country IS 'Country name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_gmt_offset IS 'Offset from GMT/UTC for the location.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.store.s_tax_precentage IS 'Applicable tax percentage for the store. Note: source column name contains a typo.';

-- retail_dimensions.time_dim
COMMENT ON COLUMN uw_team_h.retail_dimensions.time_dim.t_time_sk IS 'Surrogate key for the related time record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.time_dim.t_time_id IS 'Business identifier for the time-of-day record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.time_dim.t_time IS 'Time-of-day value or encoded time.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.time_dim.t_hour IS 'Hour component of the time.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.time_dim.t_minute IS 'Minute component of the time.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.time_dim.t_second IS 'Second component of the time.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.time_dim.t_am_pm IS 'AM/PM indicator.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.time_dim.t_shift IS 'Shift label for the time period.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.time_dim.t_sub_shift IS 'Sub-shift label for the time period.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.time_dim.t_meal_time IS 'Meal-period label associated with the time.';

-- retail_dimensions.warehouse
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_warehouse_sk IS 'Surrogate key for the related warehouse.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_warehouse_id IS 'Business identifier for the warehouse.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_warehouse_name IS 'Name of the warehouse facility.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_warehouse_sq_ft IS 'Warehouse floor space in square feet.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_street_number IS 'Street number portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_street_name IS 'Street name portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_street_type IS 'Street type or suffix for the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_suite_number IS 'Suite, unit, or apartment number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_city IS 'City name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_county IS 'County or local administrative area.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_state IS 'State or province code or name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_zip IS 'Postal or ZIP code.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_country IS 'Country name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.warehouse.w_gmt_offset IS 'Offset from GMT/UTC for the location.';

-- retail_dimensions.web_page
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_web_page_sk IS 'Surrogate key for the related web page.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_web_page_id IS 'Business identifier for the web page.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_rec_start_date IS 'Record-effective start date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_rec_end_date IS 'Record-effective end date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_creation_date_sk IS 'Surrogate key for the page creation date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_access_date_sk IS 'Surrogate key for the page access date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_autogen_flag IS 'Flag indicating whether the page was auto-generated.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_customer_sk IS 'Surrogate key for the related customer.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_url IS 'URL for the page or asset.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_type IS 'Type classification.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_char_count IS 'Character count for the page content.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_link_count IS 'Number of links on the page.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_image_count IS 'Number of images on the page.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_page.wp_max_ad_count IS 'Maximum number of ads on the page.';

-- retail_dimensions.web_site
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_site_sk IS 'Site surrogate key for the website record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_site_id IS 'Site identifier for the website record.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_rec_start_date IS 'Record-effective start date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_rec_end_date IS 'Record-effective end date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_name IS 'Name of the entity.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_open_date_sk IS 'Surrogate key for the opening date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_close_date_sk IS 'Surrogate key for the closing date.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_class IS 'Class or segment name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_manager IS 'Store manager name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_mkt_id IS 'Identifier for the market.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_mkt_class IS 'Market classification.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_mkt_desc IS 'Description of the market.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_market_manager IS 'Manager responsible for the market.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_company_id IS 'Identifier for the operating company.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_company_name IS 'Name of the company.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_street_number IS 'Street number portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_street_name IS 'Street name portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_street_type IS 'Street type or suffix for the address.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_suite_number IS 'Suite, unit, or apartment number.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_city IS 'City name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_county IS 'County or local administrative area.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_state IS 'State or province code or name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_zip IS 'Postal or ZIP code.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_country IS 'Country name.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_gmt_offset IS 'Offset from GMT/UTC for the location.';
COMMENT ON COLUMN uw_team_h.retail_dimensions.web_site.web_tax_percentage IS 'Applicable tax percentage.';

-- retail_facts.catalog_returns
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_returned_date_sk IS 'Surrogate key for the return date.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_returned_time_sk IS 'Surrogate key for the return time.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_refunded_customer_sk IS 'Surrogate key for the customer receiving the refund.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_refunded_cdemo_sk IS 'Surrogate key for the refunded customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_refunded_hdemo_sk IS 'Surrogate key for the refunded customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_refunded_addr_sk IS 'Surrogate key for the refunded customer''s address.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_returning_customer_sk IS 'Surrogate key for the customer making the return.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_returning_cdemo_sk IS 'Surrogate key for the returning customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_returning_hdemo_sk IS 'Surrogate key for the returning customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_returning_addr_sk IS 'Surrogate key for the returning customer''s address.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_call_center_sk IS 'Surrogate key for the related call center.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_catalog_page_sk IS 'Surrogate key for the related catalog page.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_ship_mode_sk IS 'Surrogate key for the related shipping mode.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_warehouse_sk IS 'Surrogate key for the related warehouse.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_reason_sk IS 'Surrogate key for the related return reason.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_order_number IS 'Order number for the transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_return_quantity IS 'Quantity returned in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_return_amount IS 'Return amount for the catalog return record.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_return_tax IS 'Tax amount associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_return_amt_inc_tax IS 'Return amount including tax.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_fee IS 'Additional fee associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_return_ship_cost IS 'Shipping cost associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_refunded_cash IS 'Cash amount refunded.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_reversed_charge IS 'Charge amount reversed.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_store_credit IS 'Store credit amount issued.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_returns.cr_net_loss IS 'Estimated net loss associated with the return.';

-- retail_facts.catalog_sales
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_sold_date_sk IS 'Surrogate key for the sale date.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_sold_time_sk IS 'Surrogate key for the sale time.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ship_date_sk IS 'Surrogate key for the shipment date.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_bill_customer_sk IS 'Surrogate key for the billed customer.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_bill_cdemo_sk IS 'Surrogate key for the billed customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_bill_hdemo_sk IS 'Surrogate key for the billed customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_bill_addr_sk IS 'Surrogate key for the billing address.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ship_customer_sk IS 'Surrogate key for the shipped-to customer.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ship_cdemo_sk IS 'Surrogate key for the shipped-to customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ship_hdemo_sk IS 'Surrogate key for the shipped-to customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ship_addr_sk IS 'Surrogate key for the shipping address.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_call_center_sk IS 'Surrogate key for the related call center.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_catalog_page_sk IS 'Surrogate key for the related catalog page.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ship_mode_sk IS 'Surrogate key for the related shipping mode.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_warehouse_sk IS 'Surrogate key for the related warehouse.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_promo_sk IS 'Surrogate key for the related promotion.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_order_number IS 'Order number for the transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_quantity IS 'Quantity sold in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_wholesale_cost IS 'Wholesale cost per unit.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_list_price IS 'List price per unit before discounts.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_sales_price IS 'Actual sales price per unit.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ext_discount_amt IS 'Extended discount amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ext_sales_price IS 'Extended sales price for the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ext_wholesale_cost IS 'Extended wholesale cost for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ext_list_price IS 'Extended list price for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ext_tax IS 'Extended tax amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_coupon_amt IS 'Coupon amount applied to the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_ext_ship_cost IS 'Extended shipping cost for the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_net_paid IS 'Net amount paid after applicable discounts.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_net_paid_inc_tax IS 'Net amount paid including tax.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_net_paid_inc_ship IS 'Net amount paid including shipping.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_net_paid_inc_ship_tax IS 'Net amount paid including shipping and tax.';
COMMENT ON COLUMN uw_team_h.retail_facts.catalog_sales.cs_net_profit IS 'Estimated net profit for the line item.';

-- retail_facts.inventory
COMMENT ON COLUMN uw_team_h.retail_facts.inventory.inv_date_sk IS 'Surrogate key for the related date record.';
COMMENT ON COLUMN uw_team_h.retail_facts.inventory.inv_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_facts.inventory.inv_warehouse_sk IS 'Surrogate key for the related warehouse.';
COMMENT ON COLUMN uw_team_h.retail_facts.inventory.inv_quantity_on_hand IS 'Inventory quantity currently on hand.';

-- retail_facts.store_returns
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_returned_date_sk IS 'Surrogate key for the return date.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_return_time_sk IS 'Surrogate key for the return time.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_customer_sk IS 'Surrogate key for the related customer.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_cdemo_sk IS 'Surrogate key for the related customer demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_hdemo_sk IS 'Surrogate key for the related household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_addr_sk IS 'Surrogate key for the related customer address.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_store_sk IS 'Surrogate key for the related store.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_reason_sk IS 'Surrogate key for the related return reason.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_ticket_number IS 'Ticket or receipt number for the retail transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_return_quantity IS 'Quantity returned in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_return_amt IS 'Monetary amount returned before tax adjustments.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_return_tax IS 'Tax amount associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_return_amt_inc_tax IS 'Return amount including tax.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_fee IS 'Additional fee associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_return_ship_cost IS 'Shipping cost associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_refunded_cash IS 'Cash amount refunded.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_reversed_charge IS 'Charge amount reversed.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_store_credit IS 'Store credit amount issued.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_returns.sr_net_loss IS 'Estimated net loss associated with the return.';

-- retail_facts.store_sales
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_sold_date_sk IS 'Surrogate key for the sale date.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_sold_time_sk IS 'Surrogate key for the sale time.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_customer_sk IS 'Surrogate key for the related customer.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_cdemo_sk IS 'Surrogate key for the related customer demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_hdemo_sk IS 'Surrogate key for the related household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_addr_sk IS 'Surrogate key for the related customer address.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_store_sk IS 'Surrogate key for the related store.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_promo_sk IS 'Surrogate key for the related promotion.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_ticket_number IS 'Ticket or receipt number for the retail transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_quantity IS 'Quantity sold in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_wholesale_cost IS 'Wholesale cost per unit.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_list_price IS 'List price per unit before discounts.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_sales_price IS 'Actual sales price per unit.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_ext_discount_amt IS 'Extended discount amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_ext_sales_price IS 'Extended sales price for the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_ext_wholesale_cost IS 'Extended wholesale cost for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_ext_list_price IS 'Extended list price for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_ext_tax IS 'Extended tax amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_coupon_amt IS 'Coupon amount applied to the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_net_paid IS 'Net amount paid after applicable discounts.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_net_paid_inc_tax IS 'Net amount paid including tax.';
COMMENT ON COLUMN uw_team_h.retail_facts.store_sales.ss_net_profit IS 'Estimated net profit for the line item.';

-- retail_facts.web_returns
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_returned_date_sk IS 'Surrogate key for the return date.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_returned_time_sk IS 'Surrogate key for the return time.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_refunded_customer_sk IS 'Surrogate key for the customer receiving the refund.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_refunded_cdemo_sk IS 'Surrogate key for the refunded customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_refunded_hdemo_sk IS 'Surrogate key for the refunded customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_refunded_addr_sk IS 'Surrogate key for the refunded customer''s address.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_returning_customer_sk IS 'Surrogate key for the customer making the return.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_returning_cdemo_sk IS 'Surrogate key for the returning customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_returning_hdemo_sk IS 'Surrogate key for the returning customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_returning_addr_sk IS 'Surrogate key for the returning customer''s address.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_web_page_sk IS 'Surrogate key for the related web page.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_reason_sk IS 'Surrogate key for the related return reason.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_order_number IS 'Order number for the transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_return_quantity IS 'Quantity returned in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_return_amt IS 'Monetary amount returned before tax adjustments.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_return_tax IS 'Tax amount associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_return_amt_inc_tax IS 'Return amount including tax.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_fee IS 'Additional fee associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_return_ship_cost IS 'Shipping cost associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_refunded_cash IS 'Cash amount refunded.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_reversed_charge IS 'Charge amount reversed.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_account_credit IS 'Account credit for the web return record.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_returns.wr_net_loss IS 'Estimated net loss associated with the return.';

-- retail_facts.web_sales
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_sold_date_sk IS 'Surrogate key for the sale date.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_sold_time_sk IS 'Surrogate key for the sale time.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ship_date_sk IS 'Surrogate key for the shipment date.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_bill_customer_sk IS 'Surrogate key for the billed customer.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_bill_cdemo_sk IS 'Surrogate key for the billed customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_bill_hdemo_sk IS 'Surrogate key for the billed customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_bill_addr_sk IS 'Surrogate key for the billing address.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ship_customer_sk IS 'Surrogate key for the shipped-to customer.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ship_cdemo_sk IS 'Surrogate key for the shipped-to customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ship_hdemo_sk IS 'Surrogate key for the shipped-to customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ship_addr_sk IS 'Surrogate key for the shipping address.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_web_page_sk IS 'Surrogate key for the related web page.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_web_site_sk IS 'Surrogate key for the related web site.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ship_mode_sk IS 'Surrogate key for the related shipping mode.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_warehouse_sk IS 'Surrogate key for the related warehouse.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_promo_sk IS 'Surrogate key for the related promotion.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_order_number IS 'Order number for the transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_quantity IS 'Quantity sold in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_wholesale_cost IS 'Wholesale cost per unit.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_list_price IS 'List price per unit before discounts.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_sales_price IS 'Actual sales price per unit.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ext_discount_amt IS 'Extended discount amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ext_sales_price IS 'Extended sales price for the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ext_wholesale_cost IS 'Extended wholesale cost for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ext_list_price IS 'Extended list price for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ext_tax IS 'Extended tax amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_coupon_amt IS 'Coupon amount applied to the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_ext_ship_cost IS 'Extended shipping cost for the line item.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_net_paid IS 'Net amount paid after applicable discounts.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_net_paid_inc_tax IS 'Net amount paid including tax.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_net_paid_inc_ship IS 'Net amount paid including shipping.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_net_paid_inc_ship_tax IS 'Net amount paid including shipping and tax.';
COMMENT ON COLUMN uw_team_h.retail_facts.web_sales.ws_net_profit IS 'Estimated net profit for the line item.';

-- retail_product.inventory
COMMENT ON COLUMN uw_team_h.retail_product.inventory.inv_date_sk IS 'Surrogate key for the related date record.';
COMMENT ON COLUMN uw_team_h.retail_product.inventory.inv_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_product.inventory.inv_warehouse_sk IS 'Surrogate key for the related warehouse.';
COMMENT ON COLUMN uw_team_h.retail_product.inventory.inv_quantity_on_hand IS 'Inventory quantity currently on hand.';

-- retail_product.item
COMMENT ON COLUMN uw_team_h.retail_product.item.i_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_item_id IS 'Item identifier for the item record.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_rec_start_date IS 'Record-effective start date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_rec_end_date IS 'Record-effective end date for slowly changing dimension tracking.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_item_desc IS 'Text description of the item.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_current_price IS 'Current selling price of the item.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_wholesale_cost IS 'Wholesale cost per unit.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_brand_id IS 'Identifier for the item brand.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_brand IS 'Brand name.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_class_id IS 'Identifier for the item class.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_class IS 'Class or segment name.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_category_id IS 'Identifier for the item category.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_category IS 'Item category name.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_manufact_id IS 'Identifier for the manufacturer.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_manufact IS 'Manufacturer name.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_size IS 'Item size attribute.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_formulation IS 'Item formulation attribute.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_color IS 'Item color attribute.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_units IS 'Package or unit-of-measure description.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_container IS 'Container or packaging type.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_manager_id IS 'Identifier for the responsible manager.';
COMMENT ON COLUMN uw_team_h.retail_product.item.i_product_name IS 'Display name of the item or product.';

-- retail_product.promotion
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_promo_sk IS 'Surrogate key for the related promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_promo_id IS 'Business identifier for the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_start_date_sk IS 'Surrogate key for the start date.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_end_date_sk IS 'Surrogate key for the end date.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_cost IS 'Cost associated with the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_response_target IS 'Target response count or conversion goal for the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_promo_name IS 'Name of the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_channel_dmail IS 'Flag indicating whether direct mail is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_channel_email IS 'Flag indicating whether email is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_channel_catalog IS 'Flag indicating whether catalog distribution is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_channel_tv IS 'Flag indicating whether television is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_channel_radio IS 'Flag indicating whether radio is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_channel_press IS 'Flag indicating whether press or print is used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_channel_event IS 'Flag indicating whether events are used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_channel_demo IS 'Flag indicating whether demonstrations are used in the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_channel_details IS 'Free-text details about the promotional channels.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_purpose IS 'Business purpose of the promotion.';
COMMENT ON COLUMN uw_team_h.retail_product.promotion.p_discount_active IS 'Flag indicating whether a discount is active.';

-- retail_product.warehouse
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_warehouse_sk IS 'Surrogate key for the related warehouse.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_warehouse_id IS 'Business identifier for the warehouse.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_warehouse_name IS 'Name of the warehouse facility.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_warehouse_sq_ft IS 'Warehouse floor space in square feet.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_street_number IS 'Street number portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_street_name IS 'Street name portion of the address.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_street_type IS 'Street type or suffix for the address.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_suite_number IS 'Suite, unit, or apartment number.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_city IS 'City name.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_county IS 'County or local administrative area.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_state IS 'State or province code or name.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_zip IS 'Postal or ZIP code.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_country IS 'Country name.';
COMMENT ON COLUMN uw_team_h.retail_product.warehouse.w_gmt_offset IS 'Offset from GMT/UTC for the location.';

-- retail_transactions.catalog_returns
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_returned_date_sk IS 'Surrogate key for the return date.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_returned_time_sk IS 'Surrogate key for the return time.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_refunded_customer_sk IS 'Surrogate key for the customer receiving the refund.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_refunded_cdemo_sk IS 'Surrogate key for the refunded customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_refunded_hdemo_sk IS 'Surrogate key for the refunded customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_refunded_addr_sk IS 'Surrogate key for the refunded customer''s address.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_returning_customer_sk IS 'Surrogate key for the customer making the return.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_returning_cdemo_sk IS 'Surrogate key for the returning customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_returning_hdemo_sk IS 'Surrogate key for the returning customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_returning_addr_sk IS 'Surrogate key for the returning customer''s address.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_call_center_sk IS 'Surrogate key for the related call center.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_catalog_page_sk IS 'Surrogate key for the related catalog page.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_ship_mode_sk IS 'Surrogate key for the related shipping mode.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_warehouse_sk IS 'Surrogate key for the related warehouse.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_reason_sk IS 'Surrogate key for the related return reason.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_order_number IS 'Order number for the transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_return_quantity IS 'Quantity returned in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_return_amount IS 'Return amount for the catalog return record.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_return_tax IS 'Tax amount associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_return_amt_inc_tax IS 'Return amount including tax.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_fee IS 'Additional fee associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_return_ship_cost IS 'Shipping cost associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_refunded_cash IS 'Cash amount refunded.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_reversed_charge IS 'Charge amount reversed.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_store_credit IS 'Store credit amount issued.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_returns.cr_net_loss IS 'Estimated net loss associated with the return.';

-- retail_transactions.catalog_sales
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_sold_date_sk IS 'Surrogate key for the sale date.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_sold_time_sk IS 'Surrogate key for the sale time.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ship_date_sk IS 'Surrogate key for the shipment date.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_bill_customer_sk IS 'Surrogate key for the billed customer.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_bill_cdemo_sk IS 'Surrogate key for the billed customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_bill_hdemo_sk IS 'Surrogate key for the billed customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_bill_addr_sk IS 'Surrogate key for the billing address.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ship_customer_sk IS 'Surrogate key for the shipped-to customer.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ship_cdemo_sk IS 'Surrogate key for the shipped-to customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ship_hdemo_sk IS 'Surrogate key for the shipped-to customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ship_addr_sk IS 'Surrogate key for the shipping address.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_call_center_sk IS 'Surrogate key for the related call center.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_catalog_page_sk IS 'Surrogate key for the related catalog page.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ship_mode_sk IS 'Surrogate key for the related shipping mode.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_warehouse_sk IS 'Surrogate key for the related warehouse.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_promo_sk IS 'Surrogate key for the related promotion.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_order_number IS 'Order number for the transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_quantity IS 'Quantity sold in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_wholesale_cost IS 'Wholesale cost per unit.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_list_price IS 'List price per unit before discounts.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_sales_price IS 'Actual sales price per unit.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ext_discount_amt IS 'Extended discount amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ext_sales_price IS 'Extended sales price for the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ext_wholesale_cost IS 'Extended wholesale cost for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ext_list_price IS 'Extended list price for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ext_tax IS 'Extended tax amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_coupon_amt IS 'Coupon amount applied to the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_ext_ship_cost IS 'Extended shipping cost for the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_net_paid IS 'Net amount paid after applicable discounts.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_net_paid_inc_tax IS 'Net amount paid including tax.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_net_paid_inc_ship IS 'Net amount paid including shipping.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_net_paid_inc_ship_tax IS 'Net amount paid including shipping and tax.';
COMMENT ON COLUMN uw_team_h.retail_transactions.catalog_sales.cs_net_profit IS 'Estimated net profit for the line item.';

-- retail_transactions.store_returns
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_returned_date_sk IS 'Surrogate key for the return date.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_return_time_sk IS 'Surrogate key for the return time.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_customer_sk IS 'Surrogate key for the related customer.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_cdemo_sk IS 'Surrogate key for the related customer demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_hdemo_sk IS 'Surrogate key for the related household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_addr_sk IS 'Surrogate key for the related customer address.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_store_sk IS 'Surrogate key for the related store.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_reason_sk IS 'Surrogate key for the related return reason.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_ticket_number IS 'Ticket or receipt number for the retail transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_return_quantity IS 'Quantity returned in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_return_amt IS 'Monetary amount returned before tax adjustments.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_return_tax IS 'Tax amount associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_return_amt_inc_tax IS 'Return amount including tax.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_fee IS 'Additional fee associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_return_ship_cost IS 'Shipping cost associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_refunded_cash IS 'Cash amount refunded.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_reversed_charge IS 'Charge amount reversed.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_store_credit IS 'Store credit amount issued.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_returns.sr_net_loss IS 'Estimated net loss associated with the return.';

-- retail_transactions.store_sales
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_sold_date_sk IS 'Surrogate key for the sale date.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_sold_time_sk IS 'Surrogate key for the sale time.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_customer_sk IS 'Surrogate key for the related customer.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_cdemo_sk IS 'Surrogate key for the related customer demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_hdemo_sk IS 'Surrogate key for the related household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_addr_sk IS 'Surrogate key for the related customer address.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_store_sk IS 'Surrogate key for the related store.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_promo_sk IS 'Surrogate key for the related promotion.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_ticket_number IS 'Ticket or receipt number for the retail transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_quantity IS 'Quantity sold in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_wholesale_cost IS 'Wholesale cost per unit.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_list_price IS 'List price per unit before discounts.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_sales_price IS 'Actual sales price per unit.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_ext_discount_amt IS 'Extended discount amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_ext_sales_price IS 'Extended sales price for the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_ext_wholesale_cost IS 'Extended wholesale cost for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_ext_list_price IS 'Extended list price for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_ext_tax IS 'Extended tax amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_coupon_amt IS 'Coupon amount applied to the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_net_paid IS 'Net amount paid after applicable discounts.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_net_paid_inc_tax IS 'Net amount paid including tax.';
COMMENT ON COLUMN uw_team_h.retail_transactions.store_sales.ss_net_profit IS 'Estimated net profit for the line item.';

-- retail_transactions.web_returns
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_returned_date_sk IS 'Surrogate key for the return date.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_returned_time_sk IS 'Surrogate key for the return time.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_refunded_customer_sk IS 'Surrogate key for the customer receiving the refund.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_refunded_cdemo_sk IS 'Surrogate key for the refunded customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_refunded_hdemo_sk IS 'Surrogate key for the refunded customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_refunded_addr_sk IS 'Surrogate key for the refunded customer''s address.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_returning_customer_sk IS 'Surrogate key for the customer making the return.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_returning_cdemo_sk IS 'Surrogate key for the returning customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_returning_hdemo_sk IS 'Surrogate key for the returning customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_returning_addr_sk IS 'Surrogate key for the returning customer''s address.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_web_page_sk IS 'Surrogate key for the related web page.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_reason_sk IS 'Surrogate key for the related return reason.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_order_number IS 'Order number for the transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_return_quantity IS 'Quantity returned in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_return_amt IS 'Monetary amount returned before tax adjustments.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_return_tax IS 'Tax amount associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_return_amt_inc_tax IS 'Return amount including tax.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_fee IS 'Additional fee associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_return_ship_cost IS 'Shipping cost associated with the return.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_refunded_cash IS 'Cash amount refunded.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_reversed_charge IS 'Charge amount reversed.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_account_credit IS 'Account credit for the web return record.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_returns.wr_net_loss IS 'Estimated net loss associated with the return.';

-- retail_transactions.web_sales
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_sold_date_sk IS 'Surrogate key for the sale date.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_sold_time_sk IS 'Surrogate key for the sale time.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ship_date_sk IS 'Surrogate key for the shipment date.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_item_sk IS 'Surrogate key for the promoted item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_bill_customer_sk IS 'Surrogate key for the billed customer.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_bill_cdemo_sk IS 'Surrogate key for the billed customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_bill_hdemo_sk IS 'Surrogate key for the billed customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_bill_addr_sk IS 'Surrogate key for the billing address.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ship_customer_sk IS 'Surrogate key for the shipped-to customer.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ship_cdemo_sk IS 'Surrogate key for the shipped-to customer''s demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ship_hdemo_sk IS 'Surrogate key for the shipped-to customer''s household demographic segment.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ship_addr_sk IS 'Surrogate key for the shipping address.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_web_page_sk IS 'Surrogate key for the related web page.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_web_site_sk IS 'Surrogate key for the related web site.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ship_mode_sk IS 'Surrogate key for the related shipping mode.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_warehouse_sk IS 'Surrogate key for the related warehouse.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_promo_sk IS 'Surrogate key for the related promotion.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_order_number IS 'Order number for the transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_quantity IS 'Quantity sold in the transaction.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_wholesale_cost IS 'Wholesale cost per unit.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_list_price IS 'List price per unit before discounts.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_sales_price IS 'Actual sales price per unit.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ext_discount_amt IS 'Extended discount amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ext_sales_price IS 'Extended sales price for the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ext_wholesale_cost IS 'Extended wholesale cost for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ext_list_price IS 'Extended list price for the line item quantity.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ext_tax IS 'Extended tax amount for the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_coupon_amt IS 'Coupon amount applied to the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_ext_ship_cost IS 'Extended shipping cost for the line item.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_net_paid IS 'Net amount paid after applicable discounts.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_net_paid_inc_tax IS 'Net amount paid including tax.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_net_paid_inc_ship IS 'Net amount paid including shipping.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_net_paid_inc_ship_tax IS 'Net amount paid including shipping and tax.';
COMMENT ON COLUMN uw_team_h.retail_transactions.web_sales.ws_net_profit IS 'Estimated net profit for the line item.';

-- travel_entities.amenities
COMMENT ON COLUMN uw_team_h.travel_entities.amenities.amenity_id IS 'Unique identifier for the amenity.';
COMMENT ON COLUMN uw_team_h.travel_entities.amenities.name IS 'Display name of the entity.';
COMMENT ON COLUMN uw_team_h.travel_entities.amenities.category IS 'Category or grouping for the amenity or entity.';
COMMENT ON COLUMN uw_team_h.travel_entities.amenities.icon IS 'Icon or symbol representing the amenity.';

-- travel_entities.countries
COMMENT ON COLUMN uw_team_h.travel_entities.countries.country IS 'Country associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_entities.countries.country_code IS 'Standard country code.';
COMMENT ON COLUMN uw_team_h.travel_entities.countries.continent IS 'Continent associated with the country.';

-- travel_entities.destinations
COMMENT ON COLUMN uw_team_h.travel_entities.destinations.destination_id IS 'Unique identifier for the destination.';
COMMENT ON COLUMN uw_team_h.travel_entities.destinations.destination IS 'Display name of the destination.';
COMMENT ON COLUMN uw_team_h.travel_entities.destinations.country IS 'Country associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_entities.destinations.state_or_province IS 'State or province for the destination.';
COMMENT ON COLUMN uw_team_h.travel_entities.destinations.state_or_province_code IS 'State or province code for the destination.';
COMMENT ON COLUMN uw_team_h.travel_entities.destinations.description IS 'Text description of the record.';

-- travel_entities.employees
COMMENT ON COLUMN uw_team_h.travel_entities.employees.employee_id IS 'Unique identifier for the employee.';
COMMENT ON COLUMN uw_team_h.travel_entities.employees.host_id IS 'Unique identifier for the host.';
COMMENT ON COLUMN uw_team_h.travel_entities.employees.name IS 'Display name of the entity.';
COMMENT ON COLUMN uw_team_h.travel_entities.employees.role IS 'Role of the employee or actor.';
COMMENT ON COLUMN uw_team_h.travel_entities.employees.email IS 'Email address associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_entities.employees.phone IS 'Phone number associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_entities.employees.country IS 'Country associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_entities.employees.joined_at IS 'Timestamp when the person joined the platform or organization.';
COMMENT ON COLUMN uw_team_h.travel_entities.employees.end_service_date IS 'Date when service or employment ended.';
COMMENT ON COLUMN uw_team_h.travel_entities.employees.is_currently_employed IS 'Flag indicating whether the employee is currently employed.';

-- travel_entities.hosts
COMMENT ON COLUMN uw_team_h.travel_entities.hosts.host_id IS 'Unique identifier for the host.';
COMMENT ON COLUMN uw_team_h.travel_entities.hosts.name IS 'Display name of the entity.';
COMMENT ON COLUMN uw_team_h.travel_entities.hosts.email IS 'Email address associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_entities.hosts.phone IS 'Phone number associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_entities.hosts.is_verified IS 'Flag indicating whether the host is verified.';
COMMENT ON COLUMN uw_team_h.travel_entities.hosts.is_active IS 'Flag indicating whether the record is currently active.';
COMMENT ON COLUMN uw_team_h.travel_entities.hosts.rating IS 'Average rating or quality score.';
COMMENT ON COLUMN uw_team_h.travel_entities.hosts.country IS 'Country associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_entities.hosts.joined_at IS 'Timestamp when the person joined the platform or organization.';

-- travel_entities.properties
COMMENT ON COLUMN uw_team_h.travel_entities.properties.property_id IS 'Unique identifier for the property.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.host_id IS 'Unique identifier for the host.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.destination_id IS 'Unique identifier for the destination.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.title IS 'Display title of the property listing.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.description IS 'Text description of the record.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.base_price IS 'Base nightly or listing price before adjustments.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.property_type IS 'Type of property, such as apartment or house.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.max_guests IS 'Maximum number of guests allowed.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.bedrooms IS 'Number of bedrooms.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.bathrooms IS 'Number of bathrooms.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.property_latitude IS 'Latitude of the property location.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.property_longitude IS 'Longitude of the property location.';
COMMENT ON COLUMN uw_team_h.travel_entities.properties.created_at IS 'Timestamp when the record was created.';

-- travel_entities.property_amenities
COMMENT ON COLUMN uw_team_h.travel_entities.property_amenities.property_id IS 'Unique identifier for the property.';
COMMENT ON COLUMN uw_team_h.travel_entities.property_amenities.amenity_id IS 'Unique identifier for the amenity.';

-- travel_entities.property_images
COMMENT ON COLUMN uw_team_h.travel_entities.property_images.image_id IS 'Image id for the property images record.';
COMMENT ON COLUMN uw_team_h.travel_entities.property_images.property_id IS 'Unique identifier for the property.';
COMMENT ON COLUMN uw_team_h.travel_entities.property_images.url IS 'URL for the image or web resource.';
COMMENT ON COLUMN uw_team_h.travel_entities.property_images.sequence IS 'Display order or sequence number.';
COMMENT ON COLUMN uw_team_h.travel_entities.property_images.is_primary IS 'Flag indicating whether this is the primary image.';
COMMENT ON COLUMN uw_team_h.travel_entities.property_images.uploaded_at IS 'Timestamp when the image was uploaded.';

-- travel_entities.users
COMMENT ON COLUMN uw_team_h.travel_entities.users.user_id IS 'Unique identifier for the user.';
COMMENT ON COLUMN uw_team_h.travel_entities.users.email IS 'Email address associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_entities.users.name IS 'Display name of the entity.';
COMMENT ON COLUMN uw_team_h.travel_entities.users.country IS 'Country associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_entities.users.user_type IS 'Type of user account or user segment.';
COMMENT ON COLUMN uw_team_h.travel_entities.users.created_at IS 'Timestamp when the record was created.';
COMMENT ON COLUMN uw_team_h.travel_entities.users.is_business IS 'Flag indicating whether the user is a business account.';
COMMENT ON COLUMN uw_team_h.travel_entities.users.company_name IS 'Company name associated with the business user.';

-- travel_events.booking_updates
COMMENT ON COLUMN uw_team_h.travel_events.booking_updates.booking_id IS 'Unique identifier for the booking.';
COMMENT ON COLUMN uw_team_h.travel_events.booking_updates.booking_update_id IS 'Unique identifier for the booking update record.';
COMMENT ON COLUMN uw_team_h.travel_events.booking_updates.check_in IS 'Check-in date or timestamp for the booking.';
COMMENT ON COLUMN uw_team_h.travel_events.booking_updates.check_out IS 'Check-out date or timestamp for the booking.';
COMMENT ON COLUMN uw_team_h.travel_events.booking_updates.created_at IS 'Timestamp when the record was created.';
COMMENT ON COLUMN uw_team_h.travel_events.booking_updates.guests_count IS 'Number of guests on the booking.';
COMMENT ON COLUMN uw_team_h.travel_events.booking_updates.property_id IS 'Unique identifier for the property.';
COMMENT ON COLUMN uw_team_h.travel_events.booking_updates.status IS 'Current status of the record or transaction.';
COMMENT ON COLUMN uw_team_h.travel_events.booking_updates.total_amount IS 'Total monetary amount for the booking or transaction.';
COMMENT ON COLUMN uw_team_h.travel_events.booking_updates.updated_at IS 'Timestamp when the record was last updated.';
COMMENT ON COLUMN uw_team_h.travel_events.booking_updates.user_id IS 'Unique identifier for the user.';

-- travel_events.bookings
COMMENT ON COLUMN uw_team_h.travel_events.bookings.booking_id IS 'Unique identifier for the booking.';
COMMENT ON COLUMN uw_team_h.travel_events.bookings.user_id IS 'Unique identifier for the user.';
COMMENT ON COLUMN uw_team_h.travel_events.bookings.property_id IS 'Unique identifier for the property.';
COMMENT ON COLUMN uw_team_h.travel_events.bookings.check_in IS 'Check-in date or timestamp for the booking.';
COMMENT ON COLUMN uw_team_h.travel_events.bookings.check_out IS 'Check-out date or timestamp for the booking.';
COMMENT ON COLUMN uw_team_h.travel_events.bookings.guests_count IS 'Number of guests on the booking.';
COMMENT ON COLUMN uw_team_h.travel_events.bookings.total_amount IS 'Total monetary amount for the booking or transaction.';
COMMENT ON COLUMN uw_team_h.travel_events.bookings.status IS 'Current status of the record or transaction.';
COMMENT ON COLUMN uw_team_h.travel_events.bookings.created_at IS 'Timestamp when the record was created.';
COMMENT ON COLUMN uw_team_h.travel_events.bookings.updated_at IS 'Timestamp when the record was last updated.';

-- travel_events.clickstream
COMMENT ON COLUMN uw_team_h.travel_events.clickstream.event IS 'Event name or event type captured in the clickstream.';
COMMENT ON COLUMN uw_team_h.travel_events.clickstream.metadata IS 'Semi-structured event metadata payload.';
COMMENT ON COLUMN uw_team_h.travel_events.clickstream.property_id IS 'Unique identifier for the property.';
COMMENT ON COLUMN uw_team_h.travel_events.clickstream.timestamp IS 'Timestamp when the event occurred.';
COMMENT ON COLUMN uw_team_h.travel_events.clickstream.user_id IS 'Unique identifier for the user.';

-- travel_events.customer_support_logs
COMMENT ON COLUMN uw_team_h.travel_events.customer_support_logs.created_at IS 'Timestamp when the record was created.';
COMMENT ON COLUMN uw_team_h.travel_events.customer_support_logs.messages IS 'Conversation messages or support log transcript.';
COMMENT ON COLUMN uw_team_h.travel_events.customer_support_logs.support_agent_id IS 'Identifier for the support agent handling the interaction.';
COMMENT ON COLUMN uw_team_h.travel_events.customer_support_logs.ticket_id IS 'Unique identifier for the support ticket.';
COMMENT ON COLUMN uw_team_h.travel_events.customer_support_logs.user_id IS 'Unique identifier for the user.';

-- travel_events.page_views
COMMENT ON COLUMN uw_team_h.travel_events.page_views.device_type IS 'Type of device used for the page view.';
COMMENT ON COLUMN uw_team_h.travel_events.page_views.page_url IS 'URL of the page that was viewed.';
COMMENT ON COLUMN uw_team_h.travel_events.page_views.property_id IS 'Unique identifier for the property.';
COMMENT ON COLUMN uw_team_h.travel_events.page_views.referrer IS 'Referring page or traffic source.';
COMMENT ON COLUMN uw_team_h.travel_events.page_views.timestamp IS 'Timestamp when the event occurred.';
COMMENT ON COLUMN uw_team_h.travel_events.page_views.user_id IS 'Unique identifier for the user.';
COMMENT ON COLUMN uw_team_h.travel_events.page_views.view_id IS 'Unique identifier for the page view event.';

-- travel_events.payments
COMMENT ON COLUMN uw_team_h.travel_events.payments.payment_id IS 'Unique identifier for the payment.';
COMMENT ON COLUMN uw_team_h.travel_events.payments.booking_id IS 'Unique identifier for the booking.';
COMMENT ON COLUMN uw_team_h.travel_events.payments.amount IS 'Monetary amount of the payment.';
COMMENT ON COLUMN uw_team_h.travel_events.payments.payment_method IS 'Payment method used for the transaction.';
COMMENT ON COLUMN uw_team_h.travel_events.payments.status IS 'Current status of the record or transaction.';
COMMENT ON COLUMN uw_team_h.travel_events.payments.payment_date IS 'Date or timestamp when the payment was made.';

-- travel_events.reviews
COMMENT ON COLUMN uw_team_h.travel_events.reviews.booking_id IS 'Unique identifier for the booking.';
COMMENT ON COLUMN uw_team_h.travel_events.reviews.comment IS 'Review comment or free-text feedback.';
COMMENT ON COLUMN uw_team_h.travel_events.reviews.created_at IS 'Timestamp when the record was created.';
COMMENT ON COLUMN uw_team_h.travel_events.reviews.is_deleted IS 'Flag indicating whether the review has been deleted.';
COMMENT ON COLUMN uw_team_h.travel_events.reviews.property_id IS 'Unique identifier for the property.';
COMMENT ON COLUMN uw_team_h.travel_events.reviews.rating IS 'Average rating or quality score.';
COMMENT ON COLUMN uw_team_h.travel_events.reviews.review_id IS 'Unique identifier for the review.';
COMMENT ON COLUMN uw_team_h.travel_events.reviews.updated_at IS 'Timestamp when the record was last updated.';
COMMENT ON COLUMN uw_team_h.travel_events.reviews.user_id IS 'Unique identifier for the user.';

-- travel_identity.countries
COMMENT ON COLUMN uw_team_h.travel_identity.countries.country IS 'Country associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_identity.countries.country_code IS 'Standard country code.';
COMMENT ON COLUMN uw_team_h.travel_identity.countries.continent IS 'Continent associated with the country.';

-- travel_identity.employees
COMMENT ON COLUMN uw_team_h.travel_identity.employees.employee_id IS 'Unique identifier for the employee.';
COMMENT ON COLUMN uw_team_h.travel_identity.employees.host_id IS 'Unique identifier for the host.';
COMMENT ON COLUMN uw_team_h.travel_identity.employees.name IS 'Display name of the entity.';
COMMENT ON COLUMN uw_team_h.travel_identity.employees.role IS 'Role of the employee or actor.';
COMMENT ON COLUMN uw_team_h.travel_identity.employees.email IS 'Email address associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_identity.employees.phone IS 'Phone number associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_identity.employees.country IS 'Country associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_identity.employees.joined_at IS 'Timestamp when the person joined the platform or organization.';
COMMENT ON COLUMN uw_team_h.travel_identity.employees.end_service_date IS 'Date when service or employment ended.';
COMMENT ON COLUMN uw_team_h.travel_identity.employees.is_currently_employed IS 'Flag indicating whether the employee is currently employed.';

-- travel_identity.hosts
COMMENT ON COLUMN uw_team_h.travel_identity.hosts.host_id IS 'Unique identifier for the host.';
COMMENT ON COLUMN uw_team_h.travel_identity.hosts.name IS 'Display name of the entity.';
COMMENT ON COLUMN uw_team_h.travel_identity.hosts.email IS 'Email address associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_identity.hosts.phone IS 'Phone number associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_identity.hosts.is_verified IS 'Flag indicating whether the host is verified.';
COMMENT ON COLUMN uw_team_h.travel_identity.hosts.is_active IS 'Flag indicating whether the record is currently active.';
COMMENT ON COLUMN uw_team_h.travel_identity.hosts.rating IS 'Average rating or quality score.';
COMMENT ON COLUMN uw_team_h.travel_identity.hosts.country IS 'Country associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_identity.hosts.joined_at IS 'Timestamp when the person joined the platform or organization.';

-- travel_identity.users
COMMENT ON COLUMN uw_team_h.travel_identity.users.user_id IS 'Unique identifier for the user.';
COMMENT ON COLUMN uw_team_h.travel_identity.users.email IS 'Email address associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_identity.users.name IS 'Display name of the entity.';
COMMENT ON COLUMN uw_team_h.travel_identity.users.country IS 'Country associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_identity.users.user_type IS 'Type of user account or user segment.';
COMMENT ON COLUMN uw_team_h.travel_identity.users.created_at IS 'Timestamp when the record was created.';
COMMENT ON COLUMN uw_team_h.travel_identity.users.is_business IS 'Flag indicating whether the user is a business account.';
COMMENT ON COLUMN uw_team_h.travel_identity.users.company_name IS 'Company name associated with the business user.';

-- travel_supply.amenities
COMMENT ON COLUMN uw_team_h.travel_supply.amenities.amenity_id IS 'Unique identifier for the amenity.';
COMMENT ON COLUMN uw_team_h.travel_supply.amenities.name IS 'Display name of the entity.';
COMMENT ON COLUMN uw_team_h.travel_supply.amenities.category IS 'Category or grouping for the amenity or entity.';
COMMENT ON COLUMN uw_team_h.travel_supply.amenities.icon IS 'Icon or symbol representing the amenity.';

-- travel_supply.destinations
COMMENT ON COLUMN uw_team_h.travel_supply.destinations.destination_id IS 'Unique identifier for the destination.';
COMMENT ON COLUMN uw_team_h.travel_supply.destinations.destination IS 'Display name of the destination.';
COMMENT ON COLUMN uw_team_h.travel_supply.destinations.country IS 'Country associated with the record.';
COMMENT ON COLUMN uw_team_h.travel_supply.destinations.state_or_province IS 'State or province for the destination.';
COMMENT ON COLUMN uw_team_h.travel_supply.destinations.state_or_province_code IS 'State or province code for the destination.';
COMMENT ON COLUMN uw_team_h.travel_supply.destinations.description IS 'Text description of the record.';
# Out:
# com.databricks.backend.common.rpc.CommandCancelledException
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:441)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:495)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:720)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:512)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:632)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$5(UsageLogging.scala:659)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:147)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# ...

# %%
# %sql
-- List all schemas in the catalog
SELECT 
  catalog_name, 
  schema_name, 
  comment 
FROM system.information_schema.schemata
WHERE catalog_name = 'uw_team_h'
ORDER BY schema_name;

-- List all tables in the catalog
SELECT 
  table_catalog, 
  table_schema, 
  table_name, 
  table_type, 
  comment 
FROM system.information_schema.tables
WHERE table_catalog = 'uw_team_h'
ORDER BY table_schema, table_name;

-- List all columns in the catalog with comments
SELECT 
  table_catalog, 
  table_schema, 
  table_name, 
  column_name, 
  data_type, 
  comment 
FROM system.information_schema.columns
WHERE table_catalog = 'uw_team_h'
ORDER BY table_schema, table_name, ordinal_position;
# Out:
# com.databricks.backend.common.rpc.CommandCancelledException
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:441)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:495)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:720)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:512)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:632)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$5(UsageLogging.scala:659)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:147)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# ...
